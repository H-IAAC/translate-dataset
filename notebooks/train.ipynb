# %%
import pandas as pd

df = pd.read_csv('/home/sildolfoneto/Documents/translate-dataset/translate_dataset/data/raw/cnn_dailymail/train.csv')
df.head(15)
# Out:
#                                           id  \
# 0   0001d1afc246a7964130f43ae940af6bc6c57f01
# 1   0002095e55fcbd3a2f366d9bf92a95433dc305ef
# 2   00027e965c8264c35cc1bc55556db388da82b07f
# 3   0002c17436637c4fe1837c935c04de47adb18e9a
# 4   0003ad6ef0c37534f80b55b4235108024b407f0b
# 5   0004306354494f090ee2d7bc5ddbf80b63e80de6
# 6   0005d61497d21ff37a17751829bd7e3b6e4a7c5c
# 7   0006021f772fad0aa78a977ce4a31b3faa6e6fe5
# 8   00083697263e215e5e7eda753070f08aa374dd45
# 9   000940f2bb357ac04a236a232156d8b9b18d1667
# 10  0009ebb1967511741629926ef9f5faea2bb6be24
# 11  000c835555db62e319854d9f8912061cdca1893e
# 12  000ca3fc9d877f8d4bb2ebd1d6858c69be571fd8
# 13  000cd1ee0098c4d510a03ddc97d11764448ebac2
# 14  000e009f6b1d954d827c9a550f3f24a5474ee82b
#
#                                               article  \
# 0   By . Associated Press . PUBLISHED: . 14:11 EST...
# 1   (CNN) -- Ralph Mata was an internal affairs li...
# 2   A drunk driver who killed a young woman in a h...
# ...

# %%
primeira_linha = df['article'].iloc[10]

# Escrever o valor em um arquivo de texto
with open('primeira_linha.txt', 'w') as arquivo_txt:
    arquivo_txt.write(primeira_linha)
